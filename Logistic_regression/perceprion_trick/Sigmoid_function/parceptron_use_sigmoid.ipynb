# %%
from sklearn.datasets import make_classification
import numpy as np
x,y=make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)

# %%
 #এমন   একটি  ফাংশন  বানাব  জাতে  সুধু  ইনপুট  ম্যাট্রিক্স  পাস  করালেই  সে  সকল  ওয়েট  ভেক্টর  রিটার্ন করে
def perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weights=np.ones(x.shape[1])
    lr=0.1
    for i in range(1000):
        j=np.random.randint(0,100)
        y_hat=step(np.dot(x[j],weights))
        weights=weights+lr*(y[j]-y_hat)*x[j]
    return weights[0],weights[1:]
def step(z):
    return 1 if z>0 else 0;

# %%
intercept_,coeficient_=perceptron(x,y)

# %%
intercept_
# Out:
# np.float64(0.9)

# %%
coeficient_
# Out:
# array([1.32920495, 0.20361391])

# %%
m=-(coeficient_[0]/coeficient_[1])
c=-(intercept_/coeficient_[1])

# %%
xin=np.linspace(-3,3,100)
yin=m*xin+c

# %%
plt.figure(figsize=(10,6))
plt.plot(xin,yin,color='red',linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
# jast without step function  we use  sigmoid function
#def step(z):
    #return 1 if z>0 else 0;
# But now we use here:
   # def sigmoid(Z):
     # return 1/(1+math.exp(-z));
def perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weights=np.ones(x.shape[1])
    lr=0.1
    for i in range(1000):
        j=np.random.randint(0,100)
        y_hat= sigmoid(np.dot(x[j],weights))
        weights=weights+lr*(y[j]-y_hat)*x[j]
    return weights[0],weights[1:]
def sigmoid(Z):
     return 1/(1+math.exp(-z));

# %%
plt.figure(figsize=(10,6))
plt.plot(xin,yin,color='red',linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
