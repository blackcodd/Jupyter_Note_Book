# %% [markdown]
# ## Outlires is those data which is far from real data
# ## Outlires can be reasone of failure on liniar regration
# ### Treatment:
# #### 1: find outlires
# #### 2:  Think about  trimming or capping
# #### 3:   Oparate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('placement.csv')

# %%
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize=(12,4))

sns.displot(df['cgpa'])

sns.displot(df['placement_exam_marks'])
plt.show()

# %%
# find min max 
mean=df['cgpa'].mean()
std=df['cgpa'].std()
min_val=mean-3*std
max_val=mean+3*std
mean,std,min_val,max_val
out=df[(df['cgpa']<min_val) | (df['cgpa']>max_val)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %%
# Trim this 
n_df= df[(df['cgpa']>min_val) & (df['cgpa']<max_val)]

# %%
n_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 991  7.04                  57.0       0
# 992  6.26                  12.0       0
# 993  6.73                  21.0       1
# 994  6.48                  63.0       0
# 998  8.62                  46.0       1
#
# [995 rows x 3 columns]

# %%
n_df.shape
# Out:
# (995, 3)

# %%
df['cgpa']=np.where(
    df['cgpa']>max_val,max_val, np.where(df['cgpa']<min_val,min_val,df['cgpa'])
);

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961499
# std         0.612688
# min         5.113546
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         8.808934
# Name: cgpa, dtype: float64
