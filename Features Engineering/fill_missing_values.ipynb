# %%
import numpy as np
import pandas as pd
import datetime as dt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
df=pd.read_csv('train.csv',usecols=)

# %%
pdf=df[]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.loc[df['city_id']==14,'city_id']=np.nan

# %%
df
# Out:
#            date  product_id  city_id  orders
# 0    2019-12-10        5628     25.0       3
# 1    2018-08-15        3646      NaN     157
# 2    2018-10-23        1859     25.0       1
# 3    2019-08-17        7292     25.0       1
# 4    2019-01-06        4344     25.0       3
# ..          ...         ...      ...     ...
# 995  2018-10-08         255     13.0       1
# 996  2018-12-06        5521      7.0       1
# 997  2019-05-07         487     26.0      14
# 998  2019-03-03        1503     21.0       2
# 999  2019-10-15        6371      7.0      22
#
# [1000 rows x 4 columns]

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
pdf
# Out:
#            date  product_id  city_id  orders
# 0    2019-12-10        5628       25       3
# 1    2018-08-15        3646       14     157
# 2    2018-10-23        1859       25       1
# 3    2019-08-17        7292       25       1
# 4    2019-01-06        4344       25       3
# ..          ...         ...      ...     ...
# 995  2018-10-08         255       13       1
# 996  2018-12-06        5521        7       1
# 997  2019-05-07         487       26      14
# 998  2019-03-03        1503       21       2
# 999  2019-10-15        6371        7      22
#
# [1000 rows x 4 columns]

# %%
df['NNcity_id_men']=df['city_id'].fillna(df['city_id'].mean())
df['NNcity_id_med']=df['city_id'].fillna(df['city_id'].median())

# %%
df
x=df.drop(columns=['date','product_id','orders'])
x
# Out:
#      city_id  NNcity_id_men  NNcity_id_med
# 0         25             25             25
# 1         14             14             14
# 2         25             25             25
# 3         25             25             25
# 4         25             25             25
# ..       ...            ...            ...
# 995       13             13             13
# 996        7              7              7
# 997       26             26             26
# 998       21             21             21
# 999        7              7              7
#
# [1000 rows x 3 columns]

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
df['city_id'].plot(kind='kde',ax=ax,color='red')
df['NNcity_id_men'].plot(kind='kde',ax=ax,color='blue')
# Out:
# <Axes: ylabel='Density'>

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
df['city_id'].plot(kind='kde',ax=ax,color='red')
df['NNcity_id_med'].plot(kind='kde',ax=ax,color='blue')
# Out:
# <Axes: ylabel='Density'>

# %%
x_train,x_test=train_test_split(df.drop(columns=['date','product_id','orders']),test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      city_id  NNcity_id_men  NNcity_id_med
# 29         0              0              0
# 535       25             25             25
# 695        1              1              1
# 557       13             13             13
# 836       23             23             23
# ..       ...            ...            ...
# 106       25             25             25
# 270       13             13             13
# 860       13             13             13
# 435       26             26             26
# 102       29             29             29
#
# [800 rows x 3 columns]

# %%
x_test
# Out:
#      city_id  NNcity_id_men  NNcity_id_med
# 521       25             25             25
# 737        2              2              2
# 740       16             16             16
# 660       23             23             23
# 411       22             22             22
# ..       ...            ...            ...
# 408       13             13             13
# 332       22             22             22
# 208        2              2              2
# 613        1              1              1
# 78         7              7              7
#
# [200 rows x 3 columns]

# %%
x_train[['city_id','NNcity_id_men','NNcity_id_med']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # same things useing sklearn lets try it::::---->
