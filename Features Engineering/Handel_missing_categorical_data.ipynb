# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df
# Out:
#      FireplaceQu GarageQual  SalePrice
# 0            NaN         TA     208500
# 1             TA         TA     181500
# 2             TA         TA     223500
# 3             Gd         TA     140000
# 4             TA         TA     250000
# ...          ...        ...        ...
# 1455          TA         TA     175000
# 1456          TA         TA     210000
# 1457          Gd         TA     266500
# 1458         NaN         TA     142125
# 1459         NaN         TA     147500
#
# [1460 rows x 3 columns]

# %%
df.isnull().mean()* 100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar() 
plt.xlabel('GarageQual')
plt.ylabel('Number_of_houses')
# Out:
# Text(0, 0.5, 'Number_of_houses')

# %%
fig=plt.figure()
ax=plt.subplot(111)
df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax)
df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='red')
lines,labels=ax.get_legend_handles_labels()
labels=['Original_variable','Imputed_variable']
ax.legend(lines,labels,loc='best')

# %%
temp=df[df['FireplaceQu']=='Gd']['SalePrice']

# %%
df['FireplaceQu'].fillna('TA',inplace=True)

# %%
fig=plt.figure()
ax=plt.subplot(111)
temp.plot(kind='kde',ax=ax)
df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax)
lines,labels=ax.get_legend_handles_labels()
labels=['Original_variable','Imputed_variable']
ax.legend(lines,labels,loc='best')

# %% [markdown]
# # the picture show that after oparating the fillna with most frequent valuse the pdf is same as previous which is good for us
